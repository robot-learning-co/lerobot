# %%
from lerobot.common.robot_devices.motors.dynamixel import DynamixelMotorsBus, DynamixelMotorsBusConfig

# %%
# bus. find motor ind
config = DynamixelMotorsBusConfig(
        port="/dev/ttyACM1",
        motors={   
                "joint1": [1, "xl330-m077"],
                "joint2": [2, "xl330-m077"],
                "joint3": [3, "xl330-m077"],
                "joint4": [4, "xl330-m077"],
                "joint5": [5, "xl330-m077"],
                "joint6": [6, "xl330-m077"],
                "gripper": [7, "xl330-m077"],
            },
    )

# %%
bus = DynamixelMotorsBus(config)
# bus.find_motor_indices()
bus.connect()
print(bus.read("Present_Position"))
# Out:
# group_readers {'Present_Position_joint1_joint2_joint3_joint4_joint5_joint6_gripper': <dynamixel_sdk.group_sync_read.GroupSyncRead object at 0x7734fadfa5c0>}
# [2906 1042 4077 1818 3558   16 1740]
